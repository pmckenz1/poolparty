# %% [markdown]
# ### imports

# %%
import scipy.stats as st
import numpy as np
import scipy.integrate as integrate
import toyplot

import poolparty

# %% [markdown]
# ## define a continuous pdf to sample from.

# %% [markdown]
# ### make a cool-shaped recombination map with all values greater than 0.

# %%
toyplot.scatterplot(np.linspace(0,1,1000), 
                   (1+1*np.cos(21*np.linspace(0,1,num=1000)+np.sin(60*np.linspace(0,1,num=1000)))), # cool equation here
                   height=300,
                   width=500);
# Out:
# <div class="toyplot" id="tb9ad626c0b7749c9bd5ca964543f857b" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="tce554e0a221143c486510fc3e1c23b08" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 300.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t5ab5e591f0d8442d90ab6344f6af6ca6"><clipPath id="t58a08c728eec414c990a335209333182"><rect height="220.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t58a08c728eec414c990a335209333182)"><g class="toyplot-mark-Point" id="tcac6fe5f4b6d45959cce21c846d52a23"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(50.0, 50.0)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(50.40040040040041, 50.32823471339318)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(50.8008008008008, 51.30729324614338)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(51.2012012012012, 52.92040889100251)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(51.6016016016016, 55.140196096065196)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(52.00200200200201, 57.929461121357534)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(52.4024024024024, 61.24228325766694)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(52.80280280280281, 65.02531710217494)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(53.2032032032032, 69.21925783654534)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(53.6036036036036, 73.76040645108066)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(54.004004004004, 78.58227055447351)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(54.40440440440441, 83.6171386774414)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(54.8048048048048, 88.7975714465349)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transf ...

# %% [markdown]
# ### does it integrate to 1 (the pdf underlying our recombination map should...)?

# %%
integrate.quad(lambda x: (1+1*np.cos(21*x+np.sin(60*x))), 0, 1)[0]
# Out:
# 1.01519239365713

# %% [markdown]
# ### nope (no surprise there), so let's find a scalar for it.

# %%
# now define scaling by that previous number:
scalar = 1 / integrate.quad(lambda x: (1+1*np.cos(21*x+np.sin(60*x))), 0, 1)[0] # one over previous line

# now look at new result (should equal 1!)
integrate.quad(lambda x: (1+1*np.cos(21*x+np.sin(60*x))) * scalar, 0, 1)[0]
# Out:
# 1.0

# %% [markdown]
# ### now look at it scaled:

# %%
toyplot.scatterplot(np.linspace(0,1,1000), 
                   (1+1*np.cos(21*np.linspace(0,1,num=1000)+np.sin(60*np.linspace(0,1,num=1000))))*scalar, # cool equation here
                   height=300,
                   width=500);
# Out:
# <div class="toyplot" id="t173a3d3fc0e24c3d9b114a4438d68966" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t46a2da0c44ea426085fa32c442c822fd" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 300.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t10b6c9d18b1d43dc891e707e666ac990"><clipPath id="tc544bc8a10274d1f8591088d62f214af"><rect height="220.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tc544bc8a10274d1f8591088d62f214af)"><g class="toyplot-mark-Point" id="ta974c6c181c949fd85224166dd263d88"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(50.0, 52.993007779028176)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(50.40040040040041, 53.3163304471687)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(50.8008008008008, 54.28073733089567)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(51.2012012012012, 55.86971263738711)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(51.6016016016016, 58.056280640587104)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(52.00200200200201, 60.80380420628708)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(52.4024024024024, 64.06704983047393)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(52.80280280280281, 67.79347042635723)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(53.2032032032032, 71.92464867451389)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(53.6036036036036, 76.39783882340404)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(54.004004004004, 81.14754354294256)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(54.40440440440441, 86.10706466861834)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(54.8048048048048, 91.20997205982869)"><circle r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opaci ...

# %% [markdown]
# ### let's set this equation as our pdf.

# %%
class my_pdf(st.rv_continuous):
    def _pdf(self,x):
        expression = (1+1*np.cos(21*x+np.sin(60*x))) * scalar # scaling by the multiplier to bring max draw down to 1
        return (expression)  # Normalized over its range, in this case [0,1]

# %%
samps=my_pdf(a=0,b=1).rvs(size=10000)
np.max(samps) # what is the maximum x-coordinate that we sample
# Out:
# 0.9999497888244988

# %%
toyplot.bars(np.histogram(samps,100),
             height=300,
             width=500);
# Out:
# <div class="toyplot" id="t46cc7ce145464524aa7a49e57e70c369" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t0c09f300c26e44f29d4ee8470db979c6" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 500.0 300.0" width="500.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tae01f3d107c944cf9258671bbcf5189e"><clipPath id="t62d59557016140939944d6b94a266c82"><rect height="220.0" width="420.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t62d59557016140939944d6b94a266c82)"><g class="toyplot-mark-BarMagnitudes" id="t3f72827a6f5b42ca8131dddc4ee9455a" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="184.97652582159625" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.999734125699746" x="50.00650295982531" y="65.02347417840375"></rect><rect class="toyplot-Datum" height="141.78403755868544" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.9997341256997316" x="54.00623708552506" y="108.21596244131455"></rect><rect class="toyplot-Datum" height="131.45539906103286" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.999734125699746" x="58.00597121122479" y="118.54460093896714"></rect><rect class="toyplot-Datum" height="92.95774647887325" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.999734125699746" x="62.005705336924535" y="157.04225352112675"></rect><rect class="toyplot-Datum" height="104.22535211267603" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.9997341256997316" x="66.00543946262428" y="145.77464788732397"></rect><rect class="toyplot-Datum" height="145.53990610328637" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.999734125699746" x="70.00517358832401" y="104.46009389671363"></rect><rect class="toyplot-Datum" height="154.92957746478874" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.999734125699746" x="74.00490771402376" y="95.07042253521128"></rect><rect class="toyplot-Datum" height="178.4037558685446" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.9997341256997316" x="78.0046418397235" y="71.59624413145539"></rect><rect class="toyplot-Datum" height="156.80751173708921" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.99973412569976" x="82.00437596542324" y="93.1924882629108"></rect><rect class="toyplot-Datum" height="96.71361502347418" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.9997341256997316" x="86.004110091123" y="153.28638497652582"></rect><rect class="toyplot-Datum" height="31.92488262910797" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="3.999734125699746" x="90.00384421682273" y="218.07511737089203"></rect><rect class="toyplot-Datum" height="0.938967136150211" style="fill:rgb(40%,76.1%,64.7%) ...

# %% [markdown]
# ## Now let's make an array of gametes!

# %%
scalar = 1 / 1.01519239365713
class my_pdf(st.rv_continuous):
    def _pdf(self,x):
        expression = (1+1*np.cos(21*x+np.sin(60*x))) * scalar # scaling by the multiplier to bring max draw down to 1
        return (expression)  # Normalized over its range, in this case [0,1]

# %%
sim_obj = poolparty.Sim_Gamete_Sequencing('/Volumes/My Passport/poolparty_sims/20gpa_500nali_1000loci_20e6reads',
                                pdf=my_pdf(a=0,b=1),
                      num_gams = 20*500,
                      gpa = 20,
                      nali=500,
                      ncutsites=1000,
                      num_reads = (20*500*1000) * 2, # amount for 1x coverage at each locus, times coverage amount
                 )

# %%
sim_obj.sim_gametes_and_sequencing()
# Out:
# Simulating gametes...
# Sequencing gametes...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-24eba55e2d57> in <module>
# ----> 1 sim_obj.sim_gametes_and_sequencing()
#
# ~/googledrive/projects/poolparty/poolparty/Sim_Gamete_Sequencing.py in sim_gametes_and_sequencing(self, evenly_spaced_loci)
#      84                             data=do_sequencing(samp_arr,
#      85                                                self.ncutsites,
# ---> 86                                                self.num_reads),
#      87                             dtype=np.int64)
#      88
#
# ~/googledrive/projects/poolparty/poolparty/utils.py in do_sequencing(arr, ncutsites, num_reads)
#      22     seqarr = np.zeros((num_reads,3),dtype=np.int64)
#      23     for rowidx in range(num_reads):
# ---> 24         seqarr[rowidx] = get_read(arr,ncutsites)
#      25     return(seqarr)
#      26
#
# ~/googledrive/projects/poolparty/poolparty/utils.py in get_read(arr, ncutsites)
#      11     alinum = np.random.randint(arr.shape[0])
#      12     colnum = np.random.randint(arr.shape[1])
# ---> 13     gamidx = arr[alinum,colnum]
#      14     cutsiteidx = np.random.randint(ncutsites)
#      15     return(alinum, gamidx, cutsiteidx)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/h5py/_hl/dataset.py in __getitem__(self, args)
#     564         # HDF5 has a bug where if the memory shape has a different rank
#     565         # than the dataset, the read is very slow
# --> 566         if len(mshape) < len(self.shape):
#     567             # pad with ones
#     568             mshape = (1,)*(len(self.shape)-len(mshape)) + mshape
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/h5py/_hl/dataset.py in shape(self)
#     285     def shape(self):
#     286         """Numpy-style shape tuple giving dataset dimensions"""
# --> 287         return self.id.shape
#     288     @shape.setter
#     289     @with_phil
#
# KeyboardInterrupt:

# %%
sim_obj = poolparty.Sim_Gamete_Sequencing('./test/',
                                pdf=my_pdf(a=0,b=1),
                      num_gams = 50,
                      gpa = 5,
                      nali=10,
                      ncutsites=100,
                      num_reads = 1000, # amount for 1x coverage at each locus, times coverage amount
                 )

# %%
sim_obj.sim_gametes_and_sequencing()
# Out:
# Simulating gametes...
# Sequencing gametes...
# Demultiplexing...
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Assigning haplotypes to loci -- this might take a while...
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
